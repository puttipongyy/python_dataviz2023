# %% [markdown]
# <a href="https://colab.research.google.com/github/puttipongyy/python_dataviz2023/blob/main/onlysr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dashboard
# [ข้อความลิงก์](https://lookerstudio.google.com/u/0/reporting/aa0c6d4c-36b4-42be-a961-45994bacfee1?fbclid=IwAR1H8wV-5K8YP2S1Dx4OmvGxZl6nEkgRryh4qbNtG-FeBLIOev-OwNvf3Z0)

# %% [markdown]
# รายชื่อสมาชิก
# - จิรภัทร กาญจนวนา 633020368-1 coding
# - นางสาวลภัสรดา แดงสูงเนิน 643020518-9 dashboard
# - นายศิริโชค ศิริวิชา 643020522-8 dashboard
# - นายธนาธิป อินทรคีรี 643021265-7 coding
# - นางสาวธิติพร ใจเอื้อ 643021266-5 dashboard
# - พุทธิพงศ์ ยางนอก 643021268-1 coding

# %% [markdown]
# ลองเพิ่มแล้วลบใน github

# %% [markdown]
# #สิ่งที่ต้องการแสดงใน dashboard

# %% [markdown]
# - กราฟเวลา 3 ช่วง
#             ช่วงที่ 1 : 2017/12/07 - 2017/12/19
#             ช่วงที่ 2 : 2019/02/13 - 2019/02/26
#             ช่วงที่ 3 : 2019/03/28 - 2019/04/10
# - แสดงยอดขายของแต่ละช่วง
# - สัดส่วนรูปแบบการชำระเงิน

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #เชื่อม ตำแหน่งของโฟลเดอร์ไดรฟ

# %%
import os
os.chdir('/content/drive/MyDrive/Dataviz_Final_thana')
# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/MyDrive/Dataviz_Final_thana

# %%
# !ls
# Out:
#  Final2023_DataViz   transactions_with_Payment.csv	  transactions_with_Time.gsheet
#  operator.csv	     transactions_with_Payment.gsheet	  ts3_test_out.csv
#  operator.gsheet    'transactions_with_Time (1).gsheet'   ts3_test_out.gsheet
#  transactions.csv    transactions_with_Time.csv

# %% [markdown]
# #อ่านไฟล์ข้อมูล

# %%
#op1 = pd.read_csv('POS_operator_logs_20171207-20171219.csv')
#op2 = pd.read_csv('POS_operator_logs_20190213-20190226.csv')
#op3 = pd.read_csv('POS_operator_logs_20190328-20190410.csv')
#ts1 =  pd.read_csv('POS_transactions_20171207-20171219.csv')
#ts2 =  pd.read_csv('POS_transactions_20190213-20190226.csv')
#ts3 =  pd.read_csv('POS_transactions_20190328-20190410.csv')

# %% [markdown]
# #กำหนดการอ่านไฟล์ว่าจะให้เป็นข้อมูลประเภทอะไร

# %%
types_dict = {'WorkstationGroupID': str, 'TranID' : str,  'BeginDateTime' : str , 'EndDateTime' : str,  'OperatorID' :  int, 'TranTime' : int, 'BreakTime' : int, 'ArtNum' : int
              , 'TNcash' : bool, 'TNcard' : bool,  'Amount' : float }

# %%
op1 = pd.read_csv('/content/drive/MyDrive/Dataviz_Final_thana/Final2023_DataViz/POS_operator_logs_20171207-20171219.csv' ,dtype = str)
op2 = pd.read_csv('/content/drive/MyDrive/Dataviz_Final_thana/Final2023_DataViz/POS_operator_logs_20190213-20190226.csv', dtype = str)
op3 = pd.read_csv('/content/drive/MyDrive/Dataviz_Final_thana/Final2023_DataViz/POS_operator_logs_20190328-20190410.csv', dtype = str)
ts1 =  pd.read_csv('/content/drive/MyDrive/Dataviz_Final_thana/Final2023_DataViz/POS_transactions_20171207-20171219.csv', dtype = types_dict  )
ts2 =  pd.read_csv('/content/drive/MyDrive/Dataviz_Final_thana/Final2023_DataViz/POS_transactions_20190213-20190226.csv', dtype = types_dict )
ts3 =  pd.read_csv('/content/drive/MyDrive/Dataviz_Final_thana/Final2023_DataViz/POS_transactions_20190328-20190410.csv', dtype = types_dict )

# %% [markdown]
# # ตรวจสอบข้อมูล

# %%
ts1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66863 entries, 0 to 66862
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  66863 non-null  object
#  1   TranID              66863 non-null  object
#  2   BeginDateTime       66863 non-null  object
#  3   EndDateTime         66863 non-null  object
#  4   OperatorID          66863 non-null  int64
#  5   TranTime            66863 non-null  int64
#  6   BreakTime           66863 non-null  int64
#  7   ArtNum              66863 non-null  int64
#  8   TNcash              66863 non-null  bool
#  9   TNcard              66863 non-null  bool
#  10  Amount              66863 non-null  float64
# dtypes: bool(2), float64(1), int64(4), object(4)
# memory usage: 4.7+ MB

# %%
op1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4708 entries, 0 to 4707
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  4708 non-null   object
#  1   WorkstationID       4708 non-null   object
#  2   TranID              4708 non-null   object
#  3   BeginDateTime       4708 non-null   object
#  4   OperatorID          4708 non-null   object
#  5   Items               4708 non-null   object
# dtypes: object(6)
# memory usage: 220.8+ KB

# %%
op1.describe()
# Out:
#        WorkstationGroupID WorkstationID         TranID        BeginDateTime  \
# count                4708          4708           4708                 4708
# unique                  2            22           4708                 4682
# top                     1            21  1712071060162  2017-12-09T14:58:02
# freq                 4520           546              1                    2
#
#        OperatorID           Items
# count        4708            4708
# unique         48               4
# top            10  OperatorSignOn
# freq          548            1264

# %%
op1.head()
# Out:
#   WorkstationGroupID WorkstationID         TranID        BeginDateTime  \
# 0                  8            16  1712071060162  2017-12-07T06:04:01
# 1                  8            15  1712071060152  2017-12-07T06:04:15
# 2                  8            14  1712071060142  2017-12-07T06:05:36
# 3                  8            18  1712071060182  2017-12-07T06:05:41
# 4                  8            17  1712071060172  2017-12-07T06:05:56
#
#   OperatorID           Items
# 0        266  OperatorSignOn
# 1        265  OperatorSignOn
# 2        264  OperatorSignOn
# 3        268  OperatorSignOn
# 4        267  OperatorSignOn

# %%
op1.head(20)
# Out:
#    WorkstationGroupID WorkstationID          TranID        BeginDateTime  \
# 0                   8            16   1712071060162  2017-12-07T06:04:01
# 1                   8            15   1712071060152  2017-12-07T06:04:15
# 2                   8            14   1712071060142  2017-12-07T06:05:36
# 3                   8            18   1712071060182  2017-12-07T06:05:41
# 4                   8            17   1712071060172  2017-12-07T06:05:56
# 5                   1            12   1712071060122  2017-12-07T07:02:30
# 6                   1            12   1712071060125  2017-12-07T07:04:20
# 7                   1            13   1712071060132  2017-12-07T07:04:42
# 8                   1            22   1712071060222  2017-12-07T07:14:01
# 9                   1            12   1712071060127  2017-12-07T07:15:57
# 10                  1            20   1712071060202  2017-12-07T07:15:55
# 11                  1             7    171207106072  2017-12-07T07:42:47
# ...

# %%
ts1[ts1['TranID'] == 1712071060162]
# Out:
# Empty DataFrame
# Columns: [WorkstationGroupID, TranID, BeginDateTime, EndDateTime, OperatorID, TranTime, BreakTime, ArtNum, TNcash, TNcard, Amount, Period]
# Index: []

# %%
op2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5218 entries, 0 to 5217
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  5218 non-null   object
#  1   WorkstationID       5218 non-null   object
#  2   TranID              5218 non-null   object
#  3   BeginDateTime       5218 non-null   object
#  4   OperatorID          5218 non-null   object
#  5   Items               5218 non-null   object
# dtypes: object(6)
# memory usage: 244.7+ KB

# %%
op2.describe()
# Out:
#        WorkstationGroupID WorkstationID           TranID        BeginDateTime  \
# count                5218          5218             5218                 5218
# unique                  2            19             5211                 5186
# top                     1             4  190226106022155  2019-02-13T05:37:55
# freq                 5100          1134                2                    2
#
#        OperatorID         Items
# count        5218          5218
# unique         45             4
# top            10  OperatorLock
# freq          518          1463

# %%
op3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4178 entries, 0 to 4177
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  4178 non-null   object
#  1   WorkstationID       4178 non-null   object
#  2   TranID              4178 non-null   object
#  3   BeginDateTime       4178 non-null   object
#  4   OperatorID          4178 non-null   object
#  5   Items               4178 non-null   object
# dtypes: object(6)
# memory usage: 196.0+ KB

# %%
op3.describe()
# Out:
#        WorkstationGroupID WorkstationID         TranID        BeginDateTime  \
# count                4178          4178           4178                 4178
# unique                  2            18           4155                 4163
# top                     1             4  1904101060172  2019-03-29T18:05:36
# freq                 4044           630              2                    2
#
#        OperatorID           Items
# count        4178            4178
# unique         50               4
# top            10  OperatorSignOn
# freq          500            1080

# %%
ts1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66863 entries, 0 to 66862
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  66863 non-null  object
#  1   TranID              66863 non-null  object
#  2   BeginDateTime       66863 non-null  object
#  3   EndDateTime         66863 non-null  object
#  4   OperatorID          66863 non-null  int64
#  5   TranTime            66863 non-null  int64
#  6   BreakTime           66863 non-null  int64
#  7   ArtNum              66863 non-null  int64
#  8   TNcash              66863 non-null  bool
#  9   TNcard              66863 non-null  bool
#  10  Amount              66863 non-null  float64
# dtypes: bool(2), float64(1), int64(4), object(4)
# memory usage: 4.7+ MB

# %%
ts1.columns
# Out:
# Index(['WorkstationGroupID', 'TranID', 'BeginDateTime', 'EndDateTime',
#        'OperatorID', 'TranTime', 'BreakTime', 'ArtNum', 'TNcash', 'TNcard',
#        'Amount'],
#       dtype='object')

# %%
ts1.describe()
# Out:
#          OperatorID      TranTime     BreakTime        ArtNum        Amount
# count  66863.000000  66863.000000  66863.000000  66863.000000  66863.000000
# mean     176.595576     73.700432     42.844623     14.343703     75.611827
# std       91.730739     64.351228     76.625655     14.895184     94.571673
# min      101.000000      1.000000      2.000000      1.000000      0.080000
# 25%      116.000000     31.000000     11.000000      5.000000     21.680000
# 50%      131.000000     56.000000     19.000000     10.000000     47.480000
# 75%      265.000000     95.000000     39.000000     19.000000     96.250000
# max      606.000000    983.000000   1199.000000    221.000000   6883.500000

# %%
ts1[~ts1['TNcash'] & ~ts1['TNcard']] # ใช้ coupon
# Out:
#       WorkstationGroupID           TranID        BeginDateTime  \
# 45                     1  171207106022532  2017-12-07T15:26:02
# 65                     1  171207106022563  2017-12-07T15:48:05
# 77                     1  171207106022580  2017-12-07T16:02:17
# 298                    1   17120810605344  2017-12-08T14:44:31
# 338                    1   17120810605406  2017-12-08T15:32:15
# ...                  ...              ...                  ...
# 66175                  1   17121810607524  2017-12-18T18:11:27
# 66187                  1   17121810607542  2017-12-18T18:24:41
# 66226                  1   17121810607606  2017-12-18T19:09:43
# 66392                  1   17121910607658  2017-12-19T19:49:35
# 66418                  1    1712071060813  2017-12-07T10:13:17
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 45     2017-12-07T15:27:15         101        73         19      33   False
# ...

# %%
ts2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47066 entries, 0 to 47065
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  47066 non-null  object
#  1   TranID              47066 non-null  object
#  2   BeginDateTime       47066 non-null  object
#  3   EndDateTime         47066 non-null  object
#  4   OperatorID          47066 non-null  int64
#  5   TranTime            47066 non-null  int64
#  6   BreakTime           47066 non-null  int64
#  7   ArtNum              47066 non-null  int64
#  8   TNcash              47066 non-null  bool
#  9   TNcard              47066 non-null  bool
#  10  Amount              47066 non-null  float64
# dtypes: bool(2), float64(1), int64(4), object(4)
# memory usage: 3.3+ MB

# %%
ts2.describe()
# Out:
#          OperatorID      TranTime     BreakTime        ArtNum        Amount
# count  47066.000000  47066.000000  47066.000000  47066.000000  47066.000000
# mean     226.645094     71.053393     42.024604     15.804020     68.645274
# std      110.838012     57.781746     73.445125     16.380067     77.816865
# min       10.000000      0.000000    -12.000000      1.000000      0.000000
# 25%      114.000000     32.000000     14.000000      5.000000     20.082500
# 50%      267.000000     56.000000     21.000000     11.000000     43.720000
# 75%      328.000000     93.000000     40.000000     21.000000     88.790000
# max      606.000000   1137.000000   1189.000000    369.000000   1654.580000

# %%
ts2[~ts2['TNcash'] & ~ts2['TNcard']] # coupon
# Out:
#       WorkstationGroupID           TranID        BeginDateTime  \
# 0                      1   19022310606223  2019-02-23T14:35:12
# 90                     1    1902141060542  2019-02-14T07:54:58
# 388                    1   19021510604101  2019-02-15T08:30:33
# 877                    1   19021810604321  2019-02-18T14:06:49
# 1586                   1   19022210605281  2019-02-22T12:39:11
# ...                  ...              ...                  ...
# 46149                  1  190215106022635  2019-02-15T18:41:33
# 46363                  1   19021810606131  2019-02-18T18:23:53
# 46602                  1   19022410607311  2019-02-24T16:55:43
# 46644                  1  190224106013139  2019-02-24T18:25:24
# 47004                  1   19022310606384  2019-02-23T17:04:38
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2019-02-23T14:35:12          10         0          2       1   False
# ...

# %%
ts2.loc[20370:20375]
# Out:
#       WorkstationGroupID          TranID        BeginDateTime  \
# 20370                  1   1902231060891  2019-02-23T11:07:13
# 20371                  1   1902231060893  2019-02-23T11:10:14
# 20372                  1   1902231060895  2019-02-23T11:11:49
# 20373                  1  19022310607118  2019-02-23T11:12:56
# 20374                  1  19022310607120  2019-02-23T11:13:47
# 20375                  1  19022310607122  2019-02-23T11:14:24
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 20370  2019-02-23T11:10:05         143       172          9      62   False
# 20371  2019-02-23T11:11:41         143        87          8      38   False
# 20372  2019-02-23T11:13:08         143        79        -12      19   False
# 20373  2019-02-23T11:12:56         143         0         51      62   False
# 20374  2019-02-23T11:14:17         143        30          7       3   False
# ...

# %%
ts3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49340 entries, 0 to 49339
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  49340 non-null  object
#  1   TranID              49340 non-null  object
#  2   BeginDateTime       49340 non-null  object
#  3   EndDateTime         49340 non-null  object
#  4   OperatorID          49340 non-null  int64
#  5   TranTime            49340 non-null  int64
#  6   BreakTime           49340 non-null  int64
#  7   ArtNum              49340 non-null  int64
#  8   TNcash              49340 non-null  bool
#  9   TNcard              49340 non-null  bool
#  10  Amount              49340 non-null  float64
# dtypes: bool(2), float64(1), int64(4), object(4)
# memory usage: 3.5+ MB

# %%
ts3.describe()
# Out:
#          OperatorID      TranTime     BreakTime        ArtNum        Amount
# count  49340.000000  49340.000000  49340.000000  49340.000000  49340.000000
# mean     189.438468     68.059972     41.272821     16.871463     72.394871
# std      106.103554     57.888295     65.739459     18.152183     84.605779
# min       10.000000      0.000000      1.000000      1.000000     -3.440000
# 25%      114.000000     30.000000     16.000000      5.000000     20.980000
# 50%      131.000000     52.000000     23.000000     11.000000     46.015000
# 75%      268.000000     88.000000     41.000000     22.000000     93.052500
# max      606.000000    994.000000   1199.000000    500.000000   4199.160000

# %%
ts3
# Out:
#       WorkstationGroupID          TranID        BeginDateTime  \
# 0                      1  19040310601356  2019-04-03T13:28:17
# 1                      1  19032910607385  2019-03-29T14:04:50
# 2                      1  19032910607386  2019-03-29T14:05:52
# 3                      1  19032910607387  2019-03-29T14:07:19
# 4                      1  19032910607389  2019-03-29T14:08:08
# ...                  ...             ...                  ...
# 49335                  1    1.904101e+14  2019-04-10T14:05:20
# 49336                  1    1.904101e+14  2019-04-10T14:06:39
# 49337                  1    1.904101e+14  2019-04-10T14:07:51
# 49338                  1    1.904101e+14  2019-04-10T14:09:46
# 49339                  1    1.904101e+14  2019-04-10T14:10:29
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2019-04-03T13:28:17          10         0          1       1   False
# ...

# %% [markdown]
# #ใส่ ช่วงเวลาของการขาย

# %%
ts1['Period'] = 1
ts2['Period'] = 2
ts3['Period'] = 3
op1['Period'] = 1
op2['Period'] = 2
op3['Period'] = 3

# %%
ts2[ts2['BreakTime'] <= 0]
# Out:
#       WorkstationGroupID         TranID        BeginDateTime  \
# 20372                  1  1902231060895  2019-02-23T11:11:49
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 20372  2019-02-23T11:13:08         143        79        -12      19   False
#
#        TNcard  Amount  Period
# 20372    True   60.47       2

# %% [markdown]
# # Cleaning ข้อมูล

# %%
ts2_clean = ts2.copy()

# %%
ts2_clean = ts2_clean[ts2_clean['BreakTime'] >= 0]
ts2_clean
# Out:
#       WorkstationGroupID          TranID        BeginDateTime  \
# 0                      1  19022310606223  2019-02-23T14:35:12
# 1                      1    190213106054  2019-02-13T07:50:14
# 2                      1    190213106055  2019-02-13T07:50:40
# 3                      1    190213106058  2019-02-13T07:54:30
# 4                      1    190213106059  2019-02-13T07:55:21
# ...                  ...             ...                  ...
# 47061                  1  19022310606490  2019-02-23T19:39:47
# 47062                  1  19022310606494  2019-02-23T19:40:59
# 47063                  1  19022310606496  2019-02-23T19:41:29
# 47064                  1  19022310606499  2019-02-23T19:42:32
# 47065                  1  19022310606500  2019-02-23T19:43:19
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 
# 1                      8            15    1712071060152  2017-12-07T06:04:15
# 2                      8            14    1712071060142  2017-12-07T06:05:36
# 3                      8            18    1712071060182  2017-12-07T06:05:41
# 4                      8            17    1712071060172  2017-12-07T06:05:56
# ...                  ...           ...              ...                  ...
# 14099                  1             3   19041010603798  2019-04-10T21:53:58
# 14100                  1             4  190410106041042  2019-04-10T21:54:30
# 14101                  1             4  190410106041044  2019-04-10T21:55:05
# 14102                  1             5   19041010605515  2019-04-10T22:00:25
# 14103                  1             4  190410106041061  2019-04-10T22:10:57
#
#       OperatorID            Items  Period
# ...

# %% [markdown]
# # ดำเนินการเกี่ยวกับ Operator ไฟล์

# %%
op_process = op_con2.copy()

# %%
op_process.describe()
# Out:
#              Period
# count  14104.000000
# mean       1.962422
# std        0.792885
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        3.000000

# %%
op_date = op_process['BeginDateTime'].str.split('T')
op_date
# Out:
# 0        [2017-12-07, 06:04:01]
# 1        [2017-12-07, 06:04:15]
# 2        [2017-12-07, 06:05:36]
# 3        [2017-12-07, 06:05:41]
# 4        [2017-12-07, 06:05:56]
#                   ...
# 14099    [2019-04-10, 21:53:58]
# 14100    [2019-04-10, 21:54:30]
# 14101    [2019-04-10, 21:55:05]
# 14102    [2019-04-10, 22:00:25]
# 14103    [2019-04-10, 22:10:57]
# Name: BeginDateTime, Length: 14104, dtype: object

# %%
op_process['Date'] = [i[0] for i in op_date]
op_process
# Out:
#       WorkstationGroupID WorkstationID           TranID        BeginDateTime  \
# 0                      8            16    1712071060162  2017-12-07T06:04:01
# 1                      8            15    1712071060152  2017-12-07T06:04:15
# 2                      8            14    1712071060142  2017-12-07T06:05:36
# 3                      8            18    1712071060182  2017-12-07T06:05:41
# 4                      8            17    1712071060172  2017-12-07T06:05:56
# ...                  ...           ...              ...                  ...
# 14099                  1             3   19041010603798  2019-04-10T21:53:58
# 14100                  1             4  190410106041042  2019-04-10T21:54:30
# 14101                  1             4  190410106041044  2019-04-10T21:55:05
# 14102                  1             5   19041010605515  2019-04-10T22:00:25
# 14103                  1             4  190410106041061  2019-04-10T22:10:57
#
# ...

# %% [markdown]
# #Sent out file Operator

# %%
op_con2.to_csv('operator.csv', index=False)

# %% [markdown]
# # ต่อตาราง Transaction

# %%
ts_con = pd.concat([ts1, ts2_clean], ignore_index=True)
ts_con
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 113923                  1   19022310606490  2019-02-23T19:39:47
# 113924                  1   19022310606494  2019-02-23T19:40:59
# 113925                  1   19022310606496  2019-02-23T19:41:29
# 113926                  1   19022310606499  2019-02-23T19:42:32
# 113927                  1   19022310606500  2019-02-23T19:43:19
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
ts_con2 = pd.concat([ts_con, ts3_clean], ignore_index=True)
ts_con2
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 163260                  1     1.904101e+14  2019-04-10T14:05:20
# 163261                  1     1.904101e+14  2019-04-10T14:06:39
# 163262                  1     1.904101e+14  2019-04-10T14:07:51
# 163263                  1     1.904101e+14  2019-04-10T14:09:46
# 163264                  1     1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
ts_con2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163265 entries, 0 to 163264
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   WorkstationGroupID  163265 non-null  object
#  1   TranID              163265 non-null  object
#  2   BeginDateTime       163265 non-null  object
#  3   EndDateTime         163265 non-null  object
#  4   OperatorID          163265 non-null  int64
#  5   TranTime            163265 non-null  int64
#  6   BreakTime           163265 non-null  int64
#  7   ArtNum              163265 non-null  int64
#  8   TNcash              163265 non-null  bool
#  9   TNcard              163265 non-null  bool
#  10  Amount              163265 non-null  float64
#  11  Period              163265 non-null  int64
# dtypes: bool(2), float64(1), int64(5), object(4)
# memory usage: 12.8+ MB

# %%
ts_con2.describe()
# Out:
#           OperatorID       TranTime      BreakTime         ArtNum  \
# count  163265.000000  163265.000000  163265.000000  163265.000000
# mean      194.903580      71.233871      42.133243      15.528809
# std       104.049699      60.634667      72.567176      16.398854
# min        10.000000       0.000000       1.000000       1.000000
# 25%       114.000000      31.000000      13.000000       5.000000
# 50%       132.000000      55.000000      21.000000      10.000000
# 75%       268.000000      92.000000      40.000000      20.000000
# max       606.000000    1137.000000    1199.000000     500.000000
#
#               Amount         Period
# count  163265.000000  163265.000000
# mean       72.632841       1.892653
# std        87.061886       0.836784
# min         0.000000       1.000000
# 25%        20.990000       1.000000
# 50%        45.910000       2.000000
# 75%        93.110000       3.000000
# max      6883.500000       3.000000

# %%
ts_con2['ArtNum'].sum()
# Out:
# 2535311

# %% [markdown]
# #add Payment Label

# %%
ts_con_process = ts_con2.copy()
ts_con_process
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 163260                  1     1.904101e+14  2019-04-10T14:05:20
# 163261                  1     1.904101e+14  2019-04-10T14:06:39
# 163262                  1     1.904101e+14  2019-04-10T14:07:51
# 163263                  1     1.904101e+14  2019-04-10T14:09:46
# 163264                  1     1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
ts_con_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163265 entries, 0 to 163264
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 1304    2017-12-14T17:45:41         101       159         28      36    True
# ...

# %%
coupon_index = ts_coupon.index
coupon_index
# Out:
# Int64Index([    45,     65,     77,    298,    338,    392,    637,    703,
#                757,    781,
#             ...
#             162436, 162437, 162453, 162463, 162883, 162903, 162904, 162987,
#             163031, 163085],
#            dtype='int64', length=1241)

# %%
cash_index = ts_cash.index
cash_index
# Out:
# Int64Index([     0,      1,      2,      3,      4,      6,      7,      8,
#                 12,     13,
#             ...
#             163253, 163254, 163256, 163257, 163258, 163259, 163260, 163262,
#             163263, 163264],
#            dtype='int64', length=83779)

# %%
card_index = ts_card.index
card_index
# Out:
# Int64Index([     5,      9,     10,     11,     15,     16,     17,     20,
#                 25,     26,
#             ...
#             163234, 163236, 163237, 163238, 163242, 163243, 163245, 163246,
#             163255, 163261],
#            dtype='int64', length=77537)

# %%
cashCard_index = ts_cashCard.index
cashCard_index
# Out:
# Int64Index([  1304,   1484,   1671,   2270,   2405,   2613,   3640,   3732,
#               4145,   4304,
#             ...
#             161199, 161329, 161724, 161769, 161976, 162291, 162748, 162793,
#             162908, 162960],
#            dtype='int64', length=708)

# %%
ts_con_process['Payment'] = [' '] * len(ts_con_process)
ts_con_process
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 163260                  1     1.904101e+14  2019-04-10T14:05:20
# 163261                  1     1.904101e+14  2019-04-10T14:06:39
# 163262                  1     1.904101e+14  2019-04-10T14:07:51
# 163263                  1     1.904101e+14  2019-04-10T14:09:46
# 163264                  1     1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %% [markdown]
# ## ใส่ Label การจ่าย

# %%
ts_con_process.loc[coupon_index, 'Payment'] = 'coupon'
ts_con_process.loc[cash_index, 'Payment'] = 'cash'
ts_con_process.loc[card_index, 'Payment'] = 'card'
ts_con_process.loc[cashCard_index, 'Payment'] = 'cash-card'

# %%
ts_con_process
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 163260                  1     1.904101e+14  2019-04-10T14:05:20
# 163261                  1     1.904101e+14  2019-04-10T14:06:39
# 163262                  1     1.904101e+14  2019-04-10T14:07:51
# 163263                  1     1.904101e+14  2019-04-10T14:09:46
# 163264                  1     1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
ts_con_process[ts_con_process['Payment'] == 'coupon']
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 45                      1  171207106022532  2017-12-07T15:26:02
# 65                      1  171207106022563  2017-12-07T15:48:05
# 77                      1  171207106022580  2017-12-07T16:02:17
# 298                     1   17120810605344  2017-12-08T14:44:31
# 338                     1   17120810605406  2017-12-08T15:32:15
# ...                   ...              ...                  ...
# 162903                  1     1.904061e+13  2019-04-06T14:03:35
# 162904                  1     1.904061e+13  2019-04-06T14:03:56
# 162987                  1     1.904061e+13  2019-04-06T17:35:28
# 163031                  1     1.904061e+13  2019-04-06T19:45:55
# 163085                  1     1.904061e+13  2019-04-06T20:48:43
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 45      2017-12-07T15:27:15         101        73         19      33   False
# ...

# %%
ts_con_process.to_csv('transactions_with_Payment.csv', index=False)

# %%
ts_con_time = ts_con_process.copy()
ts_con_time
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 163260                  1     1.904101e+14  2019-04-10T14:05:20
# 163261                  1     1.904101e+14  2019-04-10T14:06:39
# 163262                  1     1.904101e+14  2019-04-10T14:07:51
# 163263                  1     1.904101e+14  2019-04-10T14:09:46
# 163264                  1     1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
ts_con_time[['date', 'time']] = (ts_con_time.['BeginDateTime'].str.split('T', n=1, expand = True))
ts_con_time
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 163260                  1     1.904101e+14  2019-04-10T14:05:20
# 163261                  1     1.904101e+14  2019-04-10T14:06:39
# 163262                  1     1.904101e+14  2019-04-10T14:07:51
# 163263                  1     1.904101e+14  2019-04-10T14:09:46
# 163264                  1     1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %% [markdown]
# # sent out Transactions file

# %%
ts_con_time.describe()
# Out:
#           OperatorID       TranTime      BreakTime         ArtNum  \
# count  163265.000000  163265.000000  163265.000000  163265.000000
# mean      194.903580      71.233871      42.133243      15.528809
# std       104.049699      60.634667      72.567176      16.398854
# min        10.000000       0.000000       1.000000       1.000000
# 25%       114.000000      31.000000      13.000000       5.000000
# 50%       132.000000      55.000000      21.000000      10.000000
# 75%       268.000000      92.000000      40.000000      20.000000
# max       606.000000    1137.000000    1199.000000     500.000000
#
#               Amount         Period
# count  163265.000000  163265.000000
# mean       72.632841       1.892653
# std        87.061886       0.836784
# min         0.000000       1.000000
# 25%        20.990000       1.000000
# 50%        45.910000       2.000000
# 75%        93.110000       3.000000
# max      6883.500000       3.000000

# %%
ts_con_time.to_csv('transactions_with_Time.csv', index=False)

# %%
ts_con2.to_csv('transactions.csv', index=False)
